# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritvik10/Verzeo-Machine-Learning-Workshop/blob/main/Day_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/mtcars.csv")

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  ...  17.02   0   1     4     4
# 2            Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.4    6  258.0  110  ...  19.44   1   0     3     1
# 4     Hornet Sportabout  18.7    8  360.0  175  ...  17.02   0   0     3     2
# 5               Valiant  18.1    6  225.0  105  ...  20.22   1   0     3     1
# 6            Duster 360  14.3    8  360.0  245  ...  15.84   0   0     3     4
# 7             Merc 240D  24.4    4  146.7   62  ...  20.00   1   0     4     2
# 8              Merc 230  22.8    4  140.8   95  ...  22.90   1   0     4     2
# 9              Merc 280  19.2    6  167.6  123  ...  18.30   1   0     4     4
# 10            Merc 280C  17.8    6  167.6  123  ...  18.90   1   0     4     4
# ...

# %%
df.sort_values(by="mpg")
# Out:
#                   model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 15  Lincoln Continental  10.4    8  460.0  215  ...  17.82   0   0     3     4
# 14   Cadillac Fleetwood  10.4    8  472.0  205  ...  17.98   0   0     3     4
# 23           Camaro Z28  13.3    8  350.0  245  ...  15.41   0   0     3     4
# 6            Duster 360  14.3    8  360.0  245  ...  15.84   0   0     3     4
# 16    Chrysler Imperial  14.7    8  440.0  230  ...  17.42   0   0     3     4
# 30        Maserati Bora  15.0    8  301.0  335  ...  14.60   0   1     5     8
# 13          Merc 450SLC  15.2    8  275.8  180  ...  18.00   0   0     3     3
# 22          AMC Javelin  15.2    8  304.0  150  ...  17.30   0   0     3     2
# 21     Dodge Challenger  15.5    8  318.0  150  ...  16.87   0   0     3     2
# 28       Ford Pantera L  15.8    8  351.0  264  ...  14.50   0   1     5     4
# 11           Merc 450SE  16.4    8  275.8  180  ...  17.40   0   0     3     3
# ...

# %%
df.sort_values(by="mpg", ascending=False)
# Out:
#                   model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 19       Toyota Corolla  33.9    4   71.1   65  ...  19.90   1   1     4     1
# 17             Fiat 128  32.4    4   78.7   66  ...  19.47   1   1     4     1
# 27         Lotus Europa  30.4    4   95.1  113  ...  16.90   1   1     5     2
# 18          Honda Civic  30.4    4   75.7   52  ...  18.52   1   1     4     2
# 25            Fiat X1-9  27.3    4   79.0   66  ...  18.90   1   1     4     1
# 26        Porsche 914-2  26.0    4  120.3   91  ...  16.70   0   1     5     2
# 7             Merc 240D  24.4    4  146.7   62  ...  20.00   1   0     4     2
# 2            Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 8              Merc 230  22.8    4  140.8   95  ...  22.90   1   0     4     2
# 20        Toyota Corona  21.5    4  120.1   97  ...  20.01   1   0     3     1
# 31           Volvo 142E  21.4    4  121.0  109  ...  18.60   1   1     4     2
# ...

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0             Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  ...  17.02   0   1     4     4
# 2            Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 3        Hornet 4 Drive  21.4    6  258.0  110  ...  19.44   1   0     3     1
# 4     Hornet Sportabout  18.7    8  360.0  175  ...  17.02   0   0     3     2
# 5               Valiant  18.1    6  225.0  105  ...  20.22   1   0     3     1
# 6            Duster 360  14.3    8  360.0  245  ...  15.84   0   0     3     4
# 7             Merc 240D  24.4    4  146.7   62  ...  20.00   1   0     4     2
# 8              Merc 230  22.8    4  140.8   95  ...  22.90   1   0     4     2
# 9              Merc 280  19.2    6  167.6  123  ...  18.30   1   0     4     4
# 10            Merc 280C  17.8    6  167.6  123  ...  18.90   1   0     4     4
# ...

# %%
df.loc[3]
# Out:
# model    Hornet 4 Drive
# mpg                21.4
# cyl                   6
# disp                258
# hp                  110
# drat               3.08
# wt                3.215
# qsec              19.44
# vs                    1
# am                    0
# gear                  3
# carb                  1
# Name: 3, dtype: object

# %%
df.loc[0:4]
# Out:
#                model   mpg  cyl   disp   hp  ...   qsec  vs  am  gear  carb
# 0          Mazda RX4  21.0    6  160.0  110  ...  16.46   0   1     4     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  ...  17.02   0   1     4     4
# 2         Datsun 710  22.8    4  108.0   93  ...  18.61   1   1     4     1
# 3     Hornet 4 Drive  21.4    6  258.0  110  ...  19.44   1   0     3     1
# 4  Hornet Sportabout  18.7    8  360.0  175  ...  17.02   0   0     3     2
#
# [5 rows x 12 columns]

# %%
df.loc['Dodge Challenger']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-57d8a87e1be7> in <module>()
# ----> 1 df.loc['Dodge Challenger']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
# ...

# %%
df.loc[15:21, "mpg":"hp"]
# Out:
#      mpg  cyl   disp   hp
# 15  10.4    8  460.0  215
# 16  14.7    8  440.0  230
# 17  32.4    4   78.7   66
# 18  30.4    4   75.7   52
# 19  33.9    4   71.1   65
# 20  21.5    4  120.1   97
# 21  15.5    8  318.0  150

# %%
df.loc[15:21, 0:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-b8b99be2d599> in <module>()
# ----> 1 df.loc[15:21, 0:4]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1053             return self._multi_take(tup)
#    1054
# -> 1055         return self._getitem_tuple_same_dim(tup)
#    1056
#    1057     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     748                 continue
# ...

# %%
df.iloc[15:21, 0:4]
# Out:
#                   model   mpg  cyl   disp
# 15  Lincoln Continental  10.4    8  460.0
# 16    Chrysler Imperial  14.7    8  440.0
# 17             Fiat 128  32.4    4   78.7
# 18          Honda Civic  30.4    4   75.7
# 19       Toyota Corolla  33.9    4   71.1
# 20        Toyota Corona  21.5    4  120.1

# %%
df = pd.read_csv("mtcars.csv", index_col="model")

# %%
df
# Out:
#                       mpg  cyl   disp   hp  drat  ...   qsec  vs  am  gear  carb
# model                                             ...
# Mazda RX4            21.0    6  160.0  110  3.90  ...  16.46   0   1     4     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  ...  17.02   0   1     4     4
# Datsun 710           22.8    4  108.0   93  3.85  ...  18.61   1   1     4     1
# Hornet 4 Drive       21.4    6  258.0  110  3.08  ...  19.44   1   0     3     1
# Hornet Sportabout    18.7    8  360.0  175  3.15  ...  17.02   0   0     3     2
# Valiant              18.1    6  225.0  105  2.76  ...  20.22   1   0     3     1
# Duster 360           14.3    8  360.0  245  3.21  ...  15.84   0   0     3     4
# Merc 240D            24.4    4  146.7   62  3.69  ...  20.00   1   0     4     2
# Merc 230             22.8    4  140.8   95  3.92  ...  22.90   1   0     4     2
# Merc 280             19.2    6  167.6  123  3.92  ...  18.30   1   0     4     4
# ...

# %%
df.loc['Dodge Challenger']
# Out:
# mpg      15.50
# cyl       8.00
# disp    318.00
# hp      150.00
# drat      2.76
# wt        3.52
# qsec     16.87
# vs        0.00
# am        0.00
# gear      3.00
# carb      2.00
# Name: Dodge Challenger, dtype: float64

# %%
df.sort_index()
# Out:
#                       mpg  cyl   disp   hp  drat  ...   qsec  vs  am  gear  carb
# model                                             ...
# AMC Javelin          15.2    8  304.0  150  3.15  ...  17.30   0   0     3     2
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  ...  17.98   0   0     3     4
# Camaro Z28           13.3    8  350.0  245  3.73  ...  15.41   0   0     3     4
# Chrysler Imperial    14.7    8  440.0  230  3.23  ...  17.42   0   0     3     4
# Datsun 710           22.8    4  108.0   93  3.85  ...  18.61   1   1     4     1
# Dodge Challenger     15.5    8  318.0  150  2.76  ...  16.87   0   0     3     2
# Duster 360           14.3    8  360.0  245  3.21  ...  15.84   0   0     3     4
# Ferrari Dino         19.7    6  145.0  175  3.62  ...  15.50   0   1     5     6
# Fiat 128             32.4    4   78.7   66  4.08  ...  19.47   1   1     4     1
# Fiat X1-9            27.3    4   79.0   66  4.08  ...  18.90   1   1     4     1
# ...

# %%
df.iloc[:5, 0:5]
# Out:
#                     mpg  cyl   disp   hp  drat
# model
# Mazda RX4          21.0    6  160.0  110  3.90
# Mazda RX4 Wag      21.0    6  160.0  110  3.90
# Datsun 710         22.8    4  108.0   93  3.85
# Hornet 4 Drive     21.4    6  258.0  110  3.08
# Hornet Sportabout  18.7    8  360.0  175  3.15

# %%
df['mpg'].max()
# Out:
# 33.9

# %%
df.loc[df['mpg'].idxmax]
# Out:
# mpg     33.900
# cyl      4.000
# disp    71.100
# hp      65.000
# drat     4.220
# wt       1.835
# qsec    19.900
# vs       1.000
# am       1.000
# gear     4.000
# carb     1.000
# Name: Toyota Corolla, dtype: float64

# %%
df
# Out:
#                       mpg  cyl   disp   hp  drat  ...   qsec  vs  am  gear  carb
# model                                             ...
# Mazda RX4            21.0    6  160.0  110  3.90  ...  16.46   0   1     4     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  ...  17.02   0   1     4     4
# Datsun 710           22.8    4  108.0   93  3.85  ...  18.61   1   1     4     1
# Hornet 4 Drive       21.4    6  258.0  110  3.08  ...  19.44   1   0     3     1
# Hornet Sportabout    18.7    8  360.0  175  3.15  ...  17.02   0   0     3     2
# Valiant              18.1    6  225.0  105  2.76  ...  20.22   1   0     3     1
# Duster 360           14.3    8  360.0  245  3.21  ...  15.84   0   0     3     4
# Merc 240D            24.4    4  146.7   62  3.69  ...  20.00   1   0     4     2
# Merc 230             22.8    4  140.8   95  3.92  ...  22.90   1   0     4     2
# Merc 280             19.2    6  167.6  123  3.92  ...  18.30   1   0     4     4
# ...

# %%
df['gear'].unique()
# Out:
# array([4, 3, 5])

# %%
df['gear'].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['hp'], df['mpg'], color = "green", marker="*")
plt.xlabel("HP")
plt.ylabel("MPG")
plt.show()

# %%
plt.scatter(df['hp'], df['cyl'], color = "green", marker="*")
plt.xlabel("HP")
plt.ylabel("Cyl")
plt.show()

# %%
plt.scatter(df['cyl'], df['mpg'], color = "green", marker="*")
plt.xlabel("cyl")
plt.ylabel("mpg")
plt.show()
